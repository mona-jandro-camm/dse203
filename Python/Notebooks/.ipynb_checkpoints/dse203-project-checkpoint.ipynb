# %% [markdown]
# ### Henry, Hohmann, Perera
#
# [Github](https://github.com/mona-jandro-camm/dse203)
#
# # DSE203 - Data Integration & ETL
#
# - [set up environment](#00)
# - [Section 1](#01)
# - [Section 2](#02)
# - [Section 3](#03)

# %% [markdown]
# ## set up environment<a class="anchor" id="00"></a>

# %% [markdown]
# some of the packages (e.g. `dedupe` require python 3.8). if you do not already have a virtual environment set up, open a new terminal (mac) / console (windows) and run the following:
#
# ```bash
# conda create -n venv_3.8 python=3.8
#
# conda activate venv_3.8
#
# conda install jupyter
#
# conda deactivate
# ```
#
# - now close this notebook and shut down jupyter.
# -  in terminal / console run the following commands:
#
# ```bash
# conda activate venv_3.8
#
# jupyter notebook
# ```
#
# a jupyter instance should open in your browser. check that you are in the correct environment `venv_3.8` by running the following cell:

# %%
import os
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# venv_3.8

# %% [markdown]
# you can also run the following cell to see what virtual environments you have already created:

# %%
# %conda env list

# %%
# %pip install wikipedia
# %pip install dedupe
# %pip install py_stringmatching
# %pip install pytextrank
# %pip install spacy
# %pip install nltk
# %pip install gensim
# %pip install pyLDAvis
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 37.5 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import pandas as pd


import wikipedia
import json
import requests

# some of the libraries we've used so far in class
# add / remove from final deliverable as necessary
import py_stringmatching as sm
import dedupe
from sklearn.metrics import precision_score, recall_score


import spacy # language module
nlp = spacy.load("en_core_web_sm")

import nltk; nltk.download('stopwords')
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt
# %matplotlib inline

import pytextrank

import unidecode
# Out:
# [nltk_data] Downloading package stopwords to /Users/ah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /Users/ah/opt/anaconda3/envs/venv_3.8/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload

# %% [markdown]
# ## Section 1<a class="anchor" id="01"></a>

# %%
stat_files = [
    "Basic_Stats.csv"
    ,"Career_Stats_Defensive.csv"
    ,"Career_Stats_Field_Goal_Kickers.csv"
    ,"Career_Stats_Fumbles.csv"
    ,"Career_Stats_Kick_Return.csv"
    ,"Career_Stats_Kickoff.csv"
    ,"Career_Stats_Offensive_Line.csv"
    ,"Career_Stats_Passing.csv"
    ,"Career_Stats_Punt_Return.csv"
    ,"Career_Stats_Punting.csv"
    ,"Career_Stats_Receiving.csv"
    ,"Career_Stats_Rushing.csv"
    ,"Game_Logs_Defensive_Lineman.csv"
    ,"Game_Logs_Kickers.csv"
    ,"Game_Logs_Offensive_Line.csv"
    ,"Game_Logs_Punters.csv"
    ,"Game_Logs_Quarterback.csv"
    ,"Game_Logs_Runningback.csv"
    ,"Game_Logs_Wide_Receiver_and_Tight_End.csv"
]

# %%
base_url = r"https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/"

urls = [base_url + file_name for file_name in stat_files]

for url in urls:
    print(url)
# Out:
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Basic_Stats.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Defensive.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Field_Goal_Kickers.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Fumbles.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Kick_Return.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Kickoff.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Offensive_Line.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Passing.csv
# https://raw.githubusercontent.com/mona-jandro-camm/dse203/main/Datasets/Career_Stats_Punt_Return.csv
# ...

# %%
df = pd.read_csv(urls[0])
df
# Out:
#         Age        Birth Place    Birthday           College Current Status  \
# 0       NaN  Grand Rapids , MI   5/23/1921        Notre Dame        Retired
# 1       NaN        Dayton , OH  12/21/1930            Dayton        Retired
# 2      56.0        Temple , TX   9/11/1960    Louisiana Tech        Retired
# 3      30.0   New Orleans , LA   9/30/1986               LSU        Retired
# 4      25.0       Detroit , MI   3/31/1992  Central Michigan         Active
# ...     ...                ...         ...               ...            ...
# 17167  73.0       Detroit , MI   2/15/1944    Michigan State        Retired
# 17168  32.0       Worland , WY   8/19/1984       Weber State        Retired
# 17169  43.0    Washington , DC    5/4/1974             Akron        Retired
# 17170   NaN   New Willard , TX   3/30/1921            Baylor        Retired
# 17171  54.0         Bryan , TX  10/21/1962            Baylor        Retired
#
# ...

# %% [markdown]
# ## Section 2<a class="anchor" id="02"></a>

# %% [markdown]
# ## Section 3<a class="anchor" id="03"></a>
